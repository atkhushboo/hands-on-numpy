# %%
import numpy as np 

np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from numpy import array

array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from numpy import array

user = ["khush","atul","khushi","berlin"]

new_user = user +["tokyo","rio"]

print(len(new_user))

np_arr = np.array(new_user)
print(np_arr)
# Out:
# 6
# ['khush' 'atul' 'khushi' 'berlin' 'tokyo' 'rio']

# %%
import numpy as np 

height=[1.73,1.76,1.88,1.55]
np_height = np.array([height])

weight =[65.4,64.2,63.5,67.2]
np_weight = np.array([weight])

bmi = np_height / np_weight ** 2
# print(bim)
bmi
# Out:
# array([[0.00040447, 0.00042701, 0.00046624, 0.00034324]])

# %%
import numpy as np 

x= ["k",True,1,0.5]

np_x = np.array(x)
type(np_x)
print(np_x.dtype)
# Out:
# <U32

# %%
# 2D Array in NumPy  ......

import numpy as np 

arr = np.array([1,2,3])

print(arr.shape)



# 2D Array normal ....
arr =[[1,2,3,] ,[4,5,6,7]
]
print(arr)


arr_2 = np.array(arr)
print(arr_2.shape)
# Out:
# (3,)
# [[1, 2, 3], [4, 5, 6, 7]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 15
#      12 arr =[[1,2,3,] ,[4,5,6,7]
#      13 ]
#      14 print(arr)
# ---> 15 print(arr.shape)
#
# AttributeError: 'list' object has no attribute 'shape'
